# %% [markdown]
# <a href="https://colab.research.google.com/github/Deekshu966/EDA-LAB/blob/main/Copy_of_100521729087_SRI_DIKSHITHA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NLP ASSIGNMENT1

# %% [markdown]
# # 1005-21-729087_SRI DIKSHITHA

# %%
import nltk
import matplotlib.pyplot as plt

# %%
from nltk.book import*

# %% [markdown]
# # VARIOUS FREQUENCY FUNCTIONS

# %%
#Create a frequency distribution containing the given samples
fdist = FreqDist(text2)

# %%
fdist
# Out:
# FreqDist({',': 9397, 'to': 4063, '.': 3975, 'the': 3861, 'of': 3565, 'and': 3350, 'her': 2436, 'a': 2043, 'I': 2004, 'in': 1904, ...})

# %%
def frequency_distribution(text):
    return FreqDist(text)

# %%
frdit1=frequency_distribution(text2)

# %%
frdit1
# Out:
# FreqDist({',': 9397, 'to': 4063, '.': 3975, 'the': 3861, 'of': 3565, 'and': 3350, 'her': 2436, 'a': 2043, 'I': 2004, 'in': 1904, ...})

# %%
fredit1=frequency_distribution(text1)

# %%
fredit1
# Out:
# FreqDist({',': 18713, 'the': 13721, '.': 6862, 'of': 6536, 'and': 6024, 'a': 4569, 'to': 4542, ';': 4072, 'in': 3916, 'that': 2982, ...})

# %%
print(list(frdit1)[100:300])
# Out:
# ['some', 'can', 'though', 'He', 'has', 'before', 'well', 'It', 'too', 'other', 'thing', 'Lucy', 'never', 'how', 'soon', 'after', 'Mr', 'see', 'Colonel', 'we', 'without', 'nothing', 'ever', 'may', 'good', '.--', 'being', 'John', 'out', 'first', '?', 'say', 'house', 'little', 'most', 'day', 'great', ';--', 'two', 'however', 'Brandon', 'again', 'And', 'make', '!--', 'made', 'about', 'sure', 'its', 'Ferrars', 'You', 'heart', 'then', 'give', 'shall', 'always', 'man', 'even', 'room', 'thought', 'into', 'himself', 'saw', '!"', 'Sir', 'away', 'up', 'dear', 'while', 'felt', 'young', 'enough', 'myself', 'replied', 'same', 'Middleton', 'last', 'long', 'over', 'moment', 'Lady', 'many', 'left', 'mind', 'still', 'go', 'less', 'happy', 'come', 'kind', 'therefore', 'world', 'quite', 'both', 'seemed', 'They', 'cannot', 'believe', 'us', 'Barton', 'came', 'upon', 'hope', 'place', 'morning', 'cried', 'Her', 'town', 'nor', 'where', 'present', 'family', 'really', 'almost', 'brother', 'indeed', 'till', 'te
# ...

# %%
#Increment the count for this sample
def inc(frdit1 ,sample):
    frdit1[sample]+= 1
    return frdit1

# %%
frdit1 = inc(frdit1, 'the')
frdit1
# Out:
# FreqDist({',': 9397, 'to': 4063, '.': 3975, 'the': 3862, 'of': 3565, 'and': 3350, 'her': 2436, 'a': 2043, 'I': 2004, 'in': 1904, ...})

# %%
#Count of the number of times a given sample occurred
frdit1['monstrous']
# Out:
# 11

# %%
#Frequency of a given sample

frdit1.freq('monstrous')
# Out:
# 7.769678476577951e-05

# %%
#Total number of samples
frdit1.N()
# Out:
# 141576

# %%
#The samples sorted in order of decreasing frequency
frdit1.keys()
# Out:
# dict_keys(['[', 'Sense', 'and', 'Sensibility', 'by', 'Jane', 'Austen', '1811', ']', 'CHAPTER', '1', 'The', 'family', 'of', 'Dashwood', 'had', 'long', 'been', 'settled', 'in', 'Sussex', '.', 'Their', 'estate', 'was', 'large', ',', 'their', 'residence', 'at', 'Norland', 'Park', 'the', 'centre', 'property', 'where', 'for', 'many', 'generations', 'they', 'lived', 'so', 'respectable', 'a', 'manner', 'as', 'to', 'engage', 'general', 'good', 'opinion', 'surrounding', 'acquaintance', 'late', 'owner', 'this', 'single', 'man', 'who', 'very', 'advanced', 'age', 'years', 'his', 'life', 'constant', 'companion', 'housekeeper', 'sister', 'But', 'her', 'death', 'which', 'happened', 'ten', 'before', 'own', 'produced', 'great', 'alteration', 'home', ';', 'supply', 'loss', 'he', 'invited', 'received', 'into', 'house', 'nephew', 'Mr', 'Henry', 'legal', 'inheritor', 'person', 'whom', 'intended', 'bequeath', 'it', 'In', 'society', 'niece', 'children', 'old', 'Gentleman', "'", 's', 'days', 'were', 'comfort
# ...

# %%
frdit1.most_common()
# Out:
# [(',', 9397),
#  ('to', 4063),
#  ('.', 3975),
#  ('the', 3861),
#  ('of', 3565),
#  ('and', 3350),
#  ('her', 2436),
#  ('a', 2043),
#  ('I', 2004),
#  ('in', 1904),
#  ('was', 1846),
#  ('it', 1568),
#  ('"', 1506),
#  (';', 1419),
#  ('she', 1333),
#  ('be', 1305),
#  ('that', 1297),
#  ('for', 1234),
#  ('not', 1212),
#  ('as', 1179),
#  ('you', 1037),
#  ('with', 971),
#  ('had', 969),
#  ('his', 941),
#  ('he', 895),
#  ("'", 883),
#  ('have', 807),
#  ('at', 806),
#  ('by', 737),
#  ('is', 728),
#  ('."', 721),
#  ('s', 700),
#  ('Elinor', 684),
#  ('on', 676),
#  ('all', 642),
#  ('him', 633),
#  ('so', 617),
#  ('but', 597),
#  ('which', 592),
#  ('could', 568),
#  ('Marianne', 566),
#  ('my', 551),
#  ('Mrs', 530),
#  ('from', 527),
#  ('would', 507),
#  ('very', 492),
#  ('no', 488),
#  ('their', 463),
#  ('them', 462),
#  ('--', 461),
#  ('been', 440),
#  ('were', 437),
#  ('me', 433),
#  ('they', 428),
#  ('more', 406),
#  ('said', 397),
#  (',"', 396),
#  ('any', 389),
# ...

# %%
#Iterate over the samples, in order of decreasing frequency
words=[]
count=0
for word in frdit1:
    if frdit1[word]>=70:
        words.append(word)
print(words)
# Out:
# [',', 'to', '.', 'the', 'of', 'and', 'her', 'a', 'I', 'in', 'was', 'it', '"', ';', 'she', 'be', 'that', 'for', 'not', 'as', 'you', 'with', 'had', 'his', 'he', "'", 'have', 'at', 'by', 'is', '."', 's', 'Elinor', 'on', 'all', 'him', 'so', 'but', 'which', 'could', 'Marianne', 'my', 'Mrs', 'from', 'would', 'very', 'no', 'their', 'them', '--', 'been', 'were', 'me', 'they', 'more', 'said', ',"', 'any', 'what', 'this', '-', 'every', 'than', 'will', 'or', 'your', 'an', 'such', 'one', 'do', 'But', '!', 'much', 'sister', 'only', 'must', 'own', 'am', 'Edward', 'when', 'who', 'mother', 'She', 'herself', 'Dashwood', 'if', 'The', 'time', 'know', 'Jennings', 'should', 'are', 'might', 'Willoughby', '?"', 'did', 'now', 'there', 'think', 'Miss', 'some', 'can', 'though', 'He', 'has', 'before', 'well', 'It', 'too', 'other', 'thing', 'Lucy', 'never', 'how', 'soon', 'after', 'Mr', 'see', 'Colonel', 'we', 'without', 'nothing', 'ever', 'may', 'good', '.--', 'being', 'John', 'out', 'first', '?', 'say', 'hous
# ...

# %%
#Sample with the greatest count
frdit1.max()
# Out:
# ','

# %%
frdit1.tabulate()
# Out:
#                 ,                to                 .               the                of               and               her                 a                 I                in               was                it                 "                 ;               she                be              that               for               not                as               you              with               had               his                he                 '              have                at                by                is                ."                 s            Elinor                on               all               him                so               but             which             could          Marianne                my               Mrs              from             would              very                no             their              them                --              been              were                me              they              more         
# ...

# %% [markdown]
# # PLOTS

# %%
frdit1.plot()
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
frdit1.plot(cumulative=True)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Cumulative Counts'>

# %%
#Applying frequency distribution over text2
fdist2 = frequency_distribution(text5)
fdist2
# Out:
# FreqDist({'.': 1268, 'JOIN': 1021, 'PART': 1016, '?': 737, 'lol': 704, 'to': 658, 'i': 648, 'the': 646, 'you': 635, ',': 596, ...})

# %%
#updating frdit1 with counts of fdist2
frdit1 |= fdist2
frdit1
# Out:
# FreqDist({',': 9397, 'to': 4063, '.': 3975, 'the': 3861, 'of': 3565, 'and': 3350, 'her': 2436, 'a': 2043, 'I': 2004, 'in': 1904, ...})

# %%
frdit1 < fdist2 #Test if samples in fdist1 occur less frequently than in fdist2
# Out:
# False

# %% [markdown]
# # SOME WORD COMPARISON OPERATORS

# %%
x = sent7

# %%
x
# Out:
# ['Pierre',
#  'Vinken',
#  ',',
#  '61',
#  'years',
#  'old',
#  ',',
#  'will',
#  'join',
#  'the',
#  'board',
#  'as',
#  'a',
#  'nonexecutive',
#  'director',
#  'Nov.',
#  '29',
#  '.']

# %%
for s in x:
    print( s.startswith('t'))
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False

# %%
for s in x:
    print(s.endswith('t'))
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
for s in x:
    print(t in s)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# True

# %%
for s in x:
    print(s.islower())
# Out:
# False
# False
# False
# False
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# False
# False
# False

# %%
for s in x:
    print(s.isupper())
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
for s in x:
    print(s.isalpha())
# Out:
# True
# True
# False
# False
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# False
# False
# False

# %%
for s in x:
    print(s.isalnum())
# Out:
# True
# True
# False
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# False

# %%
for s in x:
    print(s.isdigit())
# Out:
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False

# %%
for s in x:
    print(s.istitle())
# Out:
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
